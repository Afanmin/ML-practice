# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
X = np.array([[1,2],[1,4],[1,0],
             [4,2],[4,4],[4,0]])
kmeans = KMeans(n_clusters=2,random_state=0).fit(X)

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, 1, 1, 1], dtype=int32)

# %%
kmeans.predict([[0,0],[2.6,4]])
# Out:
# array([0, 1], dtype=int32)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.,  2.],
#        [ 4.,  2.]])

# %%
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_blobs

# %%
X,y = make_blobs(n_samples=1000,n_features=2,centers=[[-1,-1],[0,0],[1,1],[2,2]],cluster_std=[0.4,0.2,0.2,0.2],random_state=9)

# %%
plt.scatter(X[:,0],X[:,1],marker='o')
plt.show()

# %%
y_pred = KMeans(n_clusters=4,random_state=9).fit_predict(X)
plt.scatter(X[:,0],X[:,1],c=y_pred)
plt.show()

# %%
X,y=make_blobs(n_samples=100,n_features=3,centers=4)

# %%
kmeans=KMeans(n_clusters=4)

# %%
kmeans=kmeans.fit(X)

# %%
lables=kmeans.labels_

# %%
print(lables)
# Out:
# [0 2 1 2 1 0 2 1 3 3 3 2 3 0 3 3 3 2 2 1 0 1 1 1 3 3 1 1 2 1 0 0 3 1 1 1 2
#  1 2 2 3 2 3 3 2 2 3 1 0 3 0 2 3 1 0 1 3 0 2 2 0 0 3 3 3 2 0 2 3 1 2 1 1 2
#  1 1 0 2 3 0 0 2 0 0 0 2 0 3 0 2 1 3 1 3 0 0 1 0 0 2]

# %%
kmeans.cluster_centers_
# Out:
# array([[-4.67561651, -9.06761937,  8.76517985],
#        [-9.11659176, -3.75064537, -2.58572721],
#        [-0.93044674,  7.77574304,  7.66227621],
#        [-8.42013658,  2.35917776, -2.88182994]])
